# %% [markdown]
# # Bringing it all together: cross referencing data files
# ---
#
# To wrap things up, we'll go over one big example that integrates a little bit of everything we've learned so far. This example will demonstrate a very common task in genomics: cross referencing data between different text files.
#
# ***The situation:***
#
# I'm interested in looking at the distribution of translation start sites (TSS) along the length of mRNAs. I already have a file with the locations of all the TSS in mouse (`all_start_sites.txt`). However, first I need to normalize each TSS position by gene length so that I can graph the *relative* position of TSS across all genes in my dataset. I can easily do this by dividing the start site position by the full length of the gene. Unfortunately, though, I have gene lengths stored in a separate file (`transc_lengths.txt`), so I need to somehow integrate these two pieces of information (TSS position and gene length) across the two files.
#
# Here's a picture version of what I want to do:
#
# <img align="left" src="../images/tis_normalization.PNG" />

# %% [markdown]
# And here a few lines from each of the two files I have:
#
# *`all_start_sites.txt`*
# ```
# knownGene	GeneName	InitCodon[nt]	DisttoCDS[codons]	FramevsCDS	InitContext[-3to+4]	CDSLength[codons]	HarrPeakStart	HarrPeakWidth	#HarrReads	PeakScore	Codon	Product
# uc007afd.1	Mrpl15	248	79	1	AATATGG	15	247	2	368	2.61	aug	internal-out-of-frame
# uc007afh.1	Lypla1	36	5	0	AACATGT	225	34	4	783	3.27	aug	n-term-trunc
# uc007afi.1	Tcea1	28	-24	0	GGCTTGT	325	27	3	446	1.43	nearcog	n-term-ext
# uc007afi.1	Tcea1	100	0	0	GCCATGG	301	99	3	3852	3.79	aug	canonical
# uc007afn.1	Atp6v1h	100	-13	-1	GCTATCC	10	99	3	728	0.77	nearcog	uorf
# uc007afn.1	Atp6v1h	149	3	0	AAGATGG	480	147	3	1407	1.36	aug	n-term-trunc
# uc007agb.1	Pcmtd1	120	-97	-1	GCGCTGG	45	119	3	65	0.75	nearcog	uorf
# ...
# ```
#
# *`transc_lengths.txt`*
# ```
# SeqID	Len
# uc009gmc.1	4900
# uc008mue.1	459
# uc007hzr.1	4578
# uc007gtm.1	1257
# uc007axo.1	2311
# uc007wps.1	2694
# uc007gqc.1	30
# uc009smc.1	1530
# ...
# ```
#
# The common piece of information between these files is the gene ID (`knownGene` and `SeqID`), so this is what we will use to match up start sites to gene lengths. Note that we can not count on the gene IDs to be in the same order in the two files, so we will need some other way of matching up the data. (Something like a lookup table, perhaps..)
#
# ***The plan***
#
# When working with more than one file, it sometimes helps to write down a step-by-step plan before you start coding. One way to do this is to write out your plan in the form of code comments -- then, once you're ready to code, you can just fill in what's needed under each comment.
#
# Here's my step-by-step plan for tackling this problem:
#
# ```
# 1. Open length file
# 2. For each line in length file:
#     a. Extract the gene id (1st column) and length (2nd column)
#     b. Store lengths in dictionary based on gene id (where gene IDs are the keys and lengths are the values)
# 3. Open output file
# 4. Open TSS file
# 5. For each line in tss file:<br>
#     a. Extract the id (1st column) and start site (3rd column)
#     b. Using the id, lookup the length of the gene from the hash
#     c. Divide the start position by the length of the gene
#     d. Print the result to the output file
# ```
#
# ***The code***
#
# And here's the final code. (Side note: I heavily commented this code for educational purposes, but usually you would not need so many comments!)

# %%
# input files
tssFile = "../data/all_start_sites.txt"
lenFile = "../data/transc_lengths.txt"

# output files
normOut = "../output/normalized_tss.txt"

# lookup table (dictionary) for transc lengths
lengthDict = {}


# read in lengths, store in dictionary
ins = open(lenFile, 'r')
ins.readline()                              # don't forget to skip the header!

for line in ins:
    line = line.rstrip('\r\n')
    
    linePartsList = line.split()            # split on whitespace to break line into separate pieces of data
    geneID = linePartsList[0]               # gene id is the first column, so it's stored in index 0 of linePartsList
    geneLength = int(linePartsList[1])      # gene length = second column, so it's stored in index 1. Note conversion to int!!
    
    lengthDict[geneID] = geneLength         # store len in hash labeled by the id

ins.close()


# read in TSS, use stored lengths to normalize, then print. No need to store TSS.
skipCount = 0 

output = open(normOut, 'w')
output.write("RelativePos\n")               # write header line for output file. remember to add a \n character to the end.

ins = open(tssFile, 'r')
ins.readline()                              # skip header in input file

for line in ins:
    line = line.rstrip('\r\n')
    
    linePartsList = line.split()            # split on whitespace to break line into separate pieces of data
    geneID = linePartsList[0]               # gene id is the first column, so it's the first element in the list
    tss = int(linePartsList[2])             # TSS = third column, so it's third in the list. Note conversion to int!!
    
    if geneID in lengthDict:                # make sure there is an entry in lengthDict for this id. See note below (##)
        fullLen = lengthDict[geneID]        # using the gene id as the key, lookup the length of this gene in the dictionary
        norm = tss / float(fullLen)         # get relative position of TSS. We convert one number to float to avoid int division
        output.write(str(norm) + "\n")      # write the result to output file. Note conversion to string and \n on end.
    else:
        print ">Warning: geneID", geneID, "was not in length lookup table. This gene will be skipped."
        skipCount = skipCount + 1

ins.close()
output.close()

print "Skipped", skipCount, "entries in TSS file."
# Out:
# >Warning: geneID uc007afd.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007afi.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007afi.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007agk.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007agk.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007ajl.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007amj.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007anw.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007anw.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007anw.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007anw.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007anw.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007anw.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007anw.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007anw.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007anw.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007aoq.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007aoq.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007aor.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007apj.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007app.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007app.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007app.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007app.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007app.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007app.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007app.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007app.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007aro.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007aro.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007atf.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007atl.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007atl.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007atl.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007ava.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007ava.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007avm.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007avm.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007awa.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007awa.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007awa.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007awa.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007axr.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007axr.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007axr.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007axr.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007aye.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007ayz.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007ayz.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007azj.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007bab.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007bac.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007bbc.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007bbc.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007bbc.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007bbk.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007bbk.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007bbk.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007bbs.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007bbs.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007bbs.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007bbx.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007bbx.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007bdu.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007bdu.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007bee.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007bee.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007bee.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007bee.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007bee.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007bee.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007bee.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007beq.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007bfu.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007bfu.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007bfz.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007bgl.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007bgl.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007bgl.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007bgl.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007bhn.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007bhn.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007bix.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007bix.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007bjm.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007bjm.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007bjt.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007bjt.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007bkg.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007bki.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007bki.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007bkv.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007bkv.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007blr.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007blr.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007bmd.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007bmd.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007bmd.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007bmf.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007bmf.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007bmf.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007bov.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007bov.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007bov.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007bov.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007bqn.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007bqn.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007bqn.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007bqn.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007bqn.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007bqn.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007bqn.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007bqn.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007bqn.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007bqn.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007bqn.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007bqn.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007bqp.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007bqp.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007bqp.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007bqp.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007bqp.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007bqp.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007bqp.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007bqp.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007bqu.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007bqz.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007bqz.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007brs.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007bun.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007buo.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007buo.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007buo.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007bvk.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007bvk.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007bvk.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007bwt.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007bwt.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007bym.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007bym.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007cdf.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007cdf.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007cea.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007cem.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007cem.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007cfj.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007cfj.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007cfj.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007cfj.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007cfj.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007cgz.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007cgz.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007cgz.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007cgz.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007cgz.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007cgz.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007cic.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007cis.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007cis.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007ciw.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007ciw.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007ciw.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007ciw.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007cjw.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007cjw.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007clc.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007clc.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007clp.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007clp.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007clp.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007cmy.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007cmy.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007cnx.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007cnx.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007cnx.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007cox.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007cox.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007cox.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007cox.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007cpt.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007cpt.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007cpt.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007cql.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007csh.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007csh.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007csh.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007csh.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007csh.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007csh.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007csh.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007csh.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007csh.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007csh.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007csw.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007csw.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007csw.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007ctq.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007ctq.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007ctq.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007ctq.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007ctq.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007ctq.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007ctq.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007cue.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007cux.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007cux.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007cux.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007cux.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007cux.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007cvc.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007cvc.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007cvc.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007cxe.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007cyb.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007cyb.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007cyb.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007cyb.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007cyb.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007cyb.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007czf.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007czf.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007czj.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007czo.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007czo.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007dbj.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007dbj.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007dbj.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007dbj.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007dbj.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007dbj.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007dca.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007dca.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007dca.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007dca.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007dca.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007dca.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007dca.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007dca.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007dca.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007dca.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007dca.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007dca.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007dca.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007dca.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007dcm.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007dcm.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007dcm.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007dio.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007dio.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007dio.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007dio.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007diz.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007diz.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007diz.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007dnx.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007dpn.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007dpn.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007dpn.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007dpn.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007dpn.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007dpn.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007dpw.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007dpw.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007dpw.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007dtn.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007dtn.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007dtu.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007dtu.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007dtu.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007dty.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007dvd.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007dvd.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007dvd.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007dvd.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007dvd.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007dvr.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007dvr.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007dvr.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007dvr.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007dvr.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007dvr.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007dvr.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007dvr.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007dvr.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007dvr.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007dwv.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007dwv.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007dwv.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007dwv.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007dxe.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007dxo.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007dxo.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007dxu.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007dxu.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007dxu.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007dxu.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007dye.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007dye.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007dzm.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007eao.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007eao.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007eao.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007eao.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007ecx.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007ecx.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007ecx.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007ehi.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007ehi.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007ehi.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007ehi.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007ehi.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007ehi.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007ehi.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007ehi.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007ehi.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007ehi.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007ehj.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007ehj.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007ehj.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007ehj.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007ehx.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007ehx.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007ehx.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007eid.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007eii.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007eii.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007eip.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007ejt.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007eki.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007eki.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007eki.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007eki.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007eki.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007ela.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007elt.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007elt.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007elt.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007elt.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007elt.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007elt.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007emc.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007enl.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007eox.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007epp.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007epp.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007epp.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007epx.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007epx.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007eqw.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007eqw.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007eqw.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007eqw.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007eqw.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007eqw.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007erf.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007erf.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007ern.2 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007ern.2 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007eta.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007eta.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007eta.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007eta.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007etd.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007eut.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007eut.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007ews.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007ews.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007ews.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007ews.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007ews.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007ews.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007exe.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007exe.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007exi.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007exi.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007exi.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007eyr.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007eyr.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007eyr.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007eyr.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007eyr.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007eyx.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007eyx.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007ezj.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007ezj.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007ezj.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007fbf.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007fbf.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007fcd.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007fcd.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007fcd.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007fcm.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007fcm.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007fcz.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007fdo.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007fdo.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007feh.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007ffk.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007ffk.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007ffk.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007ffx.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007ffx.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007ffx.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007ffx.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007ffx.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007fhg.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007fhg.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007fhg.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007fja.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007fkc.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007fkc.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007fkc.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007fkc.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007fke.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007fls.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007fls.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007fls.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007fls.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007fls.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007fls.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007fls.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007fls.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007fls.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007foo.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007foo.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007foo.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007fow.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007frf.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007ftm.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007ftm.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007ftm.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007ftm.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007fuz.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007fuz.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007fuz.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007fuz.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007fvt.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007fwo.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007gby.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007gby.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007gcl.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007gcn.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007gdg.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007gdg.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007gdg.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007gdg.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007gdg.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007gdg.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007gdg.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007ges.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007ges.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007ges.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007ges.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007ges.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007gew.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007gew.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007gew.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007gew.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007gew.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007gew.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007gfv.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007gfv.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007gfv.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007gfx.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007gfx.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007gfx.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007gfx.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007ggc.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007gge.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007ggk.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007ghu.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007ghu.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007ghu.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007gjr.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007gjr.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007gjr.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007gjr.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007glb.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007glb.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007glb.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007gnd.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007gnd.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007gre.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007gre.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007grh.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007grh.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007grm.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007grm.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007grx.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007grx.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007grx.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007gry.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007gry.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007gry.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007gry.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007guw.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007gwg.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007gwg.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007gwg.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007gwg.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007gwg.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007gwp.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007gwp.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007gwp.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007gwp.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007gwp.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007gwp.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007gww.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007gww.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007gxf.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007gxf.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007gxf.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007gxf.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007gxf.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007gxk.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007gxk.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007gxk.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007gxk.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007gxk.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007gxk.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007gxk.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007gxk.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007gxk.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007gxk.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007gxk.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007gxk.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007gxk.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007gxx.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007gxx.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007gzs.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007gzs.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007hae.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007hae.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007hai.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007hcb.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007hcb.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007hcb.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007hcx.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007hde.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007hde.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007hec.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007hec.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007hec.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007hec.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007hec.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007hes.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007hft.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007hft.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007hhj.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007hhj.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc007hhj.1 was not in length lookup table. This gene will be skipped.
# ...
# >Warning: geneID uc009taa.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009taa.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009taa.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009taa.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009tef.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009tef.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009tef.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009tef.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009tef.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009tef.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009tef.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009tef.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009teg.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009teg.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009teg.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009tfe.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009tfe.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009tfe.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009tgw.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009tgw.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009tkf.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009tkf.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009tmr.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009tmr.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009tmr.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009tng.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009tng.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009tng.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009tng.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009tnj.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009tnj.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009tnj.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009tnj.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009toc.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009toc.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009tol.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009tom.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009tom.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009tom.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009ton.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009ton.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009ton.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009ton.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009ton.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009tot.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009tpo.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009tpo.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009tpo.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009tqj.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009trb.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009trb.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009trb.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009tre.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009tre.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009tre.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009tre.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009tre.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009tss.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009tus.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009tus.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009tvz.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009twh.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009twh.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009twh.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009twh.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009twh.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009twh.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009twh.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009twh.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009twh.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009twh.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009twx.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009txs.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009txs.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009tyc.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009tyc.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009tyc.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009tyc.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009tyc.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009tyc.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009tyk.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009uaf.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009uaf.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009ucj.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009ugf.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009ugf.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009ugj.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009ugj.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009ugj.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009ugj.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009ugj.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009ugj.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009uhz.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009uhz.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009uhz.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009uia.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009uia.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009uia.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009uia.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009uia.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009uic.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009uic.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009uic.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009uic.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009uie.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009uie.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009uie.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009uie.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009uil.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009uil.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009uil.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009uil.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009uil.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009uil.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009uil.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009ukv.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009ukv.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009ukv.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009uky.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009uky.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009ulj.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009ums.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009ums.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009ums.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009ums.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009ums.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009umu.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009umu.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009umu.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009umu.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009umu.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009umu.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009umu.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009umu.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009umu.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009umu.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009umu.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009umu.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009uou.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009uou.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009uou.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009uou.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009uou.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009uox.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009uox.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009upx.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009upx.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009upx.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009upx.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009uqc.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009uqc.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009uqc.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009uqc.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009uqc.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009uqc.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009uqc.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009uqt.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009uqt.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009uqt.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009uqt.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009uqt.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009uqt.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009uqt.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009uqt.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009uqt.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009uqt.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009uug.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009uug.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009uug.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009uug.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009uug.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009uuq.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009uvl.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009uvl.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009uvl.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009uvl.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009uvl.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009uvl.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009uxw.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009uxw.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009uxw.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009uxw.1 was not in length lookup table. This gene will be skipped.
# >Warning: geneID uc009uzm.1 was not in length lookup table. This gene will be skipped.
# Skipped 4920 entries in TSS file.

# %% [markdown]
# **(##) Note: Why do we have the line "`if geneID in lengthDict:`"?**
#
# If there are gene IDs in the TSS file that were not included in the length file, then we will get an error when we try to look up that ID in the lengthDict (because it's just not there). As you can see from the output above, this is exactly what would have happened to us had we not included this `if` statement (try removing it yourself and see what happens).
#
# Whenever you think there is a chance this sort of thing might happen (and there almost always is in genomics, unfortunately) just add a quick `if` statement like the one here, which will let you skip over any IDs that would cause an error.
#
# It's also usually a good idea to print out a message whenever you skip data, like we do in the `else:` statement above. However, this can sometimes cause your code output to get out of hand (as it does here), so sometimes it's better to just print the count of how many data points were skipped.
#
# ***Code output***
#
# The main output of this code is a new file called `normalized_tss.txt` that contains all of the normalized TSS positions in a single column. Here's what it looks like:
#
# ```
# RelativePos
# 0.0147118921128
# 0.0506072874494
# 0.0754048582996
# 0.0229226361032
# 0.0506208213945
# 0.0787010506208
# 0.140783190067
# 0.170009551098
# 0.0329929300864
# ...
# ```
#
# These data can then be plotted in the form of a histogram. We won't go over plotting here, but here's an example of a plot generated using ggplot2 in R:
#
# <img align="left" src="../images/tss_dist.PNG" />

# %% [markdown]
# From this we can conclude that the majority of TSS occur in the first 10% of the gene length, which is pretty much what we would expect.
